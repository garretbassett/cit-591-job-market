# %%
import pandas as pd
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException

# %%
def get_jobs(role, location, num_jobs):
    
    # Set up driver
    
    options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(executable_path='''/Users/garret-bassett/Desktop/cit-591-projects/final-project/chromedriver''', options=options)
    
    # Navigate to page
    
    url = ('https://www.glassdoor.com/Job/jobs.htm?sc.keyword="' 
           + role 
           + '&locT=C&locId=' 
           + location 
           + '&jobType=all&minSalary=0&radius=100&remoteWorkType=0')
        
    driver.get(url)
    
    # Create and fill jobs array
    jobs = []
    
    while len(jobs) <= num_jobs:
        sleep(5)
        
        try:
            driver.find_element_by_class_name("SVGInline-svg modal_closeIcon-svg").click()
        except NoSuchElementException:
            pass
        
        try:
            driver.find_element_by_class_name("jl") # .click()
        except ElementClickInterceptedException:
            sleep(.5)
            webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()
            pass
        
        job_listings = driver.find_elements_by_class_name("jl")
        for job_listing in job_listings:
            
            print("Job " + str(len(jobs)) + " of " + str(num_jobs))
            webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()
            job_listing.click()
            sleep(1)
            # collected_successfully = False
            
            try:
                job_title = driver.find_element_by_xpath('.//div[contains(@class, "title")]').text
                job_description = driver.find_element_by_xpath('.//div[@class="jobDescriptionContent desc"]').text
                company_name = driver.find_element_by_xpath('.//div[@class="employerName"]').text
                location = driver.find_element_by_xpath('.//div[@class="location"]').text
#                 collected_successfully = True
            except:
                pass
        
            try:
                salary_estimate = driver.find_element_by_xpath('.//span[@class="gray small salary"]').text
            except NoSuchElementException:
                salary_estimate = -1 #You need to set a "not found value. It's important."
            
            try:
                rating = driver.find_element_by_xpath('.//span[@class="rating"]').text
            except NoSuchElementException:
                rating = -1 #You need to set a "not found value. It's important."
                
            try:
                industry = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Industry"]//following-sibling::*').text
            except NoSuchElementException:
                industry = -1
                
            jobs.append({"Job Title" : job_title,
            "Salary Estimate" : salary_estimate,
            "Job Description" : job_description,
            "Rating" : rating,
            "Company Name" : company_name,
            "Location" : location,
            "Industry" : industry

        try:
            driver.find_element_by_xpath('.//li[@class="next"]//a').click()
        except NoSuchElementException:
            print("Scraping terminated before reaching target number of jobs. Needed {}, got {}.".format(num_jobs, len(jobs)))
            break
            
    return pd.DataFrame(jobs)
# Out:
#   File "<ipython-input-28-96a1d0bf3153>", line 77
#     try:
#       ^
# SyntaxError: invalid syntax

# %%
# Dictionary with location codes for URL search. It's hacky - hoping to find a 
# more scalable solution but preferred this to typing the keywords into the search bar

location_codes_short = {
    "san francisco" : 1147401
    , "los angeles" : 1146821
    , "seattle" : 1150505
    , "austin" : 1139761
    , "chicago" : 1128808
    , "new york city" : 1132348
    , "boston" : 1154532
    , "philadelphia" : 1152672
}

location_codes = {
    "san francisco" : 1147401
    , "los angeles" : 1146821
    , "san diego" : 1147311
    , "seattle" : 1150505
    , "portland" : 1151614
    , "las vegas" : 1149603
    , "phoenix" : 1133904
    , "salt lake city" : 1128289
    , "denver" : 1148170
    , "austin" : 1139761
    , "dallas" : 1139977
    , "houston" : 1140171
    , "st louis" : 1131270
    , "minneapolis" : 1142551
    , "chicago" : 1128808
    , "nashville" : 1144541
    , "detroit" : 1134644
    , "columbus" : 1145845
    , "charlotte" : 1138644
    , "atlanta" : 1155583
    , "orlando" : 1154247
    , "miami" : 1154170
    , "washington dc" : 1138213
    , "new york city" : 1132348
    , "boston" : 1154532
    , "pittsburgh" : 1152990
    , "philadelphia" : 1152672
}

role_keywords = [
    "data scientist"
    , "software engineer"
    , "analyst"
#     , "manager"
#     , "teacher"
#     , "nurse"
]

# %%
df_list = list()

for location in location_codes_short:
    for role in role_keywords:
        df = get_jobs(role, location, 5)
        df_list.append(df)

# df = get_jobs("data scientist", "1128289", 5)
df_list
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-30-35ba2cc57860> in <module>
#       3 for location in location_codes_short:
#       4     for role in role_keywords:
# ----> 5         df = get_jobs(role, location, 5)
#       6         df_list.append(df)
#       7
#
# <ipython-input-18-687f150791c7> in get_jobs(role, location, num_jobs)
#      28
#      29         try:
# ---> 30             driver.find_element_by_class_name("jl") # .click()
#      31         except ElementClickInterceptedException:
#      32             sleep(.5)
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
# ...

# %%
# DEPRECATED: Sign in
    
#     sign_in_url = "https://www.glassdoor.com/index.htm"
#     driver.get(sign_in_url)
    
#     username = driver.find_element_by_id("userEmail")
#     password = driver.find_element_by_id("userPassword")

#     username.send_keys("garb@seas.upenn.edu")
#     password.send_keys("*******")  -- need to create config file

#     driver.find_element_by_name("submit").click()
